# %% [markdown]
# <a href="https://colab.research.google.com/github/Mushfi-q/Dec-16-2-week3/blob/main/scrapetestipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# **BASE URL**

# %%
url='https://books.toscrape.com/'

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text, 'html')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
soup.find('ul', class_='row')

# %%
text=soup.find_all('ul')[2].get_text()
#cleanedCategory=[]
cleanedCategory=" ".join(text.split())
print(cleanedCategory)
# Out:
# Travel Mystery Historical Fiction Sequential Art Classics Philosophy Romance Womens Fiction Fiction Childrens Religion Nonfiction Music Default Science Fiction Sports and Games Add a comment Fantasy New Adult Young Adult Science Poetry Paranormal Art Psychology Autobiography Parenting Adult Fiction Humor Horror History Food and Drink Christian Fiction Business Biography Thriller Contemporary Spirituality Academic Self Help Historical Christian Suspense Short Stories Novels Health Politics Cultural Erotica Crime

# %%
ol=soup.find_all('ol')[0]
names=ol.find_all('h3')
cleanedNamesTravel=[]
for name in names:
    cleanedNamesTravel.append(name.get_text())
print(cleanedNamesTravel)
# Out:
# ['A Light in the ...', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History ...', 'The Requiem Red', 'The Dirty Little Secrets ...', 'The Coming Woman: A ...', 'The Boys in the ...', 'The Black Maria', 'Starving Hearts (Triangular Trade ...', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little ...", 'Rip it Up and ...', 'Our Band Could Be ...', 'Olio', 'Mesaerion: The Best Science ...', 'Libertarianism for Beginners', "It's Only the Himalayas"]

# %%
import pandas as pd
from urllib.parse import urljoin

# %%
df=pd.DataFrame(columns=cleanedCategory.split())
df
# Out:
# Empty DataFrame
# Columns: [Travel, Mystery, Historical, Fiction, Sequential, Art, Classics, Philosophy, Romance, Womens, Fiction, Fiction, Childrens, Religion, Nonfiction, Music, Default, Science, Fiction, Sports, and, Games, Add, a, comment, Fantasy, New, Adult, Young, Adult, Science, Poetry, Paranormal, Art, Psychology, Autobiography, Parenting, Adult, Fiction, Humor, Horror, History, Food, and, Drink, Christian, Fiction, Business, Biography, Thriller, Contemporary, Spirituality, Academic, Self, Help, Historical, Christian, Suspense, Short, Stories, Novels, Health, Politics, Cultural, Erotica, Crime]
# Index: []
#
# [0 rows x 66 columns]

# %%
df['Travel']=cleanedNamesTravel
df.index+=1
df
# Out:
#                                    Travel Mystery Historical Fiction  \
# 1                      A Light in the ...     NaN        NaN     NaN
# 2                      Tipping the Velvet     NaN        NaN     NaN
# 3                              Soumission     NaN        NaN     NaN
# 4                           Sharp Objects     NaN        NaN     NaN
# 5            Sapiens: A Brief History ...     NaN        NaN     NaN
# 6                         The Requiem Red     NaN        NaN     NaN
# 7            The Dirty Little Secrets ...     NaN        NaN     NaN
# 8                 The Coming Woman: A ...     NaN        NaN     NaN
# 9                     The Boys in the ...     NaN        NaN     NaN
# 10                        The Black Maria     NaN        NaN     NaN
# 11  Starving Hearts (Triangular Trade ...     NaN        NaN     NaN
# 12                  Shakespeare's Sonnets     NaN        NaN     NaN
# 13                            Set Me Free     NaN        NaN     NaN
# ...

# %%
catATag=soup.find('ul',class_='nav nav-list').find('ul').find_all('a')
catATag
# Out:
# [<a href="catalogue/category/books/travel_2/index.html">
#
#                                  Travel
#
#                          </a>,
#  <a href="catalogue/category/books/mystery_3/index.html">
#
#                                  Mystery
#
#                          </a>,
#  <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>,
#  <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                  Sequential Art
#
#                          </a>,
#  <a href="catalogue/category/books/classics_6/index.html">
#
#                                  Classics
#
#                          </a>,
#  <a href="catalogue/category/books/philosophy_7/index.html">
#
#                                  Philosophy
#
#                          </a>,
#  <a href="catalogue/category/books/romance_8/index.html">
#
#                                  Romance
#
# ...

# %%
catLinkName=[]
for a in catATag:
  catLinkName.append({
        "url": a.get("href"),
        "caption": a.get_text(strip=True)
    })

catLinkName
# Out:
# [{'url': 'catalogue/category/books/travel_2/index.html', 'caption': 'Travel'},
#  {'url': 'catalogue/category/books/mystery_3/index.html',
#   'caption': 'Mystery'},
#  {'url': 'catalogue/category/books/historical-fiction_4/index.html',
#   'caption': 'Historical Fiction'},
#  {'url': 'catalogue/category/books/sequential-art_5/index.html',
#   'caption': 'Sequential Art'},
#  {'url': 'catalogue/category/books/classics_6/index.html',
#   'caption': 'Classics'},
#  {'url': 'catalogue/category/books/philosophy_7/index.html',
#   'caption': 'Philosophy'},
#  {'url': 'catalogue/category/books/romance_8/index.html',
#   'caption': 'Romance'},
#  {'url': 'catalogue/category/books/womens-fiction_9/index.html',
#   'caption': 'Womens Fiction'},
#  {'url': 'catalogue/category/books/fiction_10/index.html',
#   'caption': 'Fiction'},
#  {'url': 'catalogue/category/books/childrens_11/index.html',
#   'caption': 'Childrens'},
#  {'url': 'catalogue/category/books/religion_12/index.html',
# ...

# %%
category=pd.DataFrame(catLinkName)
category.index+=1
category
# Out:
#                                                   url             caption
# 1        catalogue/category/books/travel_2/index.html              Travel
# 2       catalogue/category/books/mystery_3/index.html             Mystery
# 3   catalogue/category/books/historical-fiction_4/...  Historical Fiction
# 4   catalogue/category/books/sequential-art_5/inde...      Sequential Art
# 5      catalogue/category/books/classics_6/index.html            Classics
# 6    catalogue/category/books/philosophy_7/index.html          Philosophy
# 7       catalogue/category/books/romance_8/index.html             Romance
# 8   catalogue/category/books/womens-fiction_9/inde...      Womens Fiction
# 9      catalogue/category/books/fiction_10/index.html             Fiction
# 10   catalogue/category/books/childrens_11/index.html           Childrens
# 11    catalogue/category/books/religion_12/index.html            Religion
# 12  catalogue/category/books/nonfiction_13/index.html          Nonfiction
# ...

# %% [markdown]
# **Category URL and Name**

# %%
category['url'] = [
    urljoin(url, urll) for urll in category['url']
]
category
# Out:
#                                                   url             caption
# 1   https://books.toscrape.com/catalogue/category/...              Travel
# 2   https://books.toscrape.com/catalogue/category/...             Mystery
# 3   https://books.toscrape.com/catalogue/category/...  Historical Fiction
# 4   https://books.toscrape.com/catalogue/category/...      Sequential Art
# 5   https://books.toscrape.com/catalogue/category/...            Classics
# 6   https://books.toscrape.com/catalogue/category/...          Philosophy
# 7   https://books.toscrape.com/catalogue/category/...             Romance
# 8   https://books.toscrape.com/catalogue/category/...      Womens Fiction
# 9   https://books.toscrape.com/catalogue/category/...             Fiction
# 10  https://books.toscrape.com/catalogue/category/...           Childrens
# 11  https://books.toscrape.com/catalogue/category/...            Religion
# 12  https://books.toscrape.com/catalogue/category/...          Nonfiction
# ...

# %%
category_name=[]
category_url=[]

for _, row in category.iterrows():
    category_name.append(row["caption"])
    category_url.append(row["url"])
print(category_name)
print(category_url)
# Out:
# ['Travel', 'Mystery', 'Historical Fiction', 'Sequential Art', 'Classics', 'Philosophy', 'Romance', 'Womens Fiction', 'Fiction', 'Childrens', 'Religion', 'Nonfiction', 'Music', 'Default', 'Science Fiction', 'Sports and Games', 'Add a comment', 'Fantasy', 'New Adult', 'Young Adult', 'Science', 'Poetry', 'Paranormal', 'Art', 'Psychology', 'Autobiography', 'Parenting', 'Adult Fiction', 'Humor', 'Horror', 'History', 'Food and Drink', 'Christian Fiction', 'Business', 'Biography', 'Thriller', 'Contemporary', 'Spirituality', 'Academic', 'Self Help', 'Historical', 'Christian', 'Suspense', 'Short Stories', 'Novels', 'Health', 'Politics', 'Cultural', 'Erotica', 'Crime']
# ...

# %% [markdown]
# **Next page url**

# %%
def get_all_pages(category_url):
  pages=[]
  currentUrl=category_url
  while True:
    #print(f"Scraping page: {currentUrl}")
    pages.append(currentUrl)

    page=requests.get(currentUrl)
    soup=BeautifulSoup(page.text, 'html')

    nxtBtn=soup.find('li',class_='next')

    if nxtBtn:
      nxtPage= nxtBtn.find('a')["href"]
      currentUrl=urljoin(currentUrl,nxtPage)
    else:
      break

  return pages

# %%
for i in range(1,len(category['url'])):
  test_category_url = category.loc[i ,"url"]
  pages= get_all_pages(test_category_url)

  print("\nTotal pages found:", len(pages))
  print(pages)
# Out:
# Total pages found: 1
# ['https://books.toscrape.com/catalogue/category/books/travel_2/index.html']
#
# Total pages found: 2
# ['https://books.toscrape.com/catalogue/category/books/mystery_3/index.html', 'https://books.toscrape.com/catalogue/category/books/mystery_3/page-2.html']
#
# Total pages found: 2
# ['https://books.toscrape.com/catalogue/category/books/historical-fiction_4/index.html', 'https://books.toscrape.com/catalogue/category/books/historical-fiction_4/page-2.html']
#
# Total pages found: 4
# ['https://books.toscrape.com/catalogue/category/books/sequential-art_5/index.html', 'https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-2.html', 'https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-3.html', 'https://books.toscrape.com/catalogue/category/books/sequential-art_5/page-4.html']
#
# Total pages found: 1
# ['https://books.toscrape.com/catalogue/category/books/classics_6/index.html']
#
# Total pages found: 1
# ...

# %% [markdown]
# **Books Url**

# %%
def getAllBooksUrl(current_Url):
  booksUrl=[]

  pages=get_all_pages(current_Url)

  for url in pages:
    response=requests.get(url)
    soup=BeautifulSoup(response.text, 'html')

    articles= soup.find_all('article', class_="product_pod")

    for article in articles:
      relLink=article.find('h3').find('a')['href']
      fullLink=urljoin(current_Url,relLink)
      booksUrl.append(fullLink)

  return booksUrl

# %% [markdown]
# **Extract details**

# %%
ratingMap={
    'One':1,
    'Two':2,
    'Three':3,
    'Four':4,
    'Five':5
}

def bookDetails(booksUrl):
  response=requests.get(booksUrl)
  response.encoding = "utf-8"
  soup=BeautifulSoup(response.text, 'html')

  #title
  title=soup.find('h1').get_text(strip=True)

  #category
  category=soup.find('ul',class_='breadcrumb').find_all('a')[2].get_text(strip=True)

  #price
  priceText=soup.find('p',class_='price_color').get_text()
  price=float(priceText.replace("£", ""))

  #availability
  availability_text = soup.find("p", class_="availability").get_text(strip=True)
  availability = "In stock" if "In stock" in availability_text else "Out of stock"

  #rating
  rating=soup.find('p',class_='star-rating')['class'][1]
  rating=ratingMap[rating]

  #image url
  imgRel=soup.find('div',class_='item active').find('img')['src']
  img=urljoin(booksUrl,imgRel)

  return {
      "title":title,
      "category":category,
      "price":price,
      "availability":availability,
      "rating":rating,
      "product_url":booksUrl,
      "img":img
  }

# %%
all_books = []

for _, row in category.iterrows():
    category_url = row["url"]

    book_urls = getAllBooksUrl(category_url)

    for url in book_urls:
        book_data = bookDetails(url)
        all_books.append(book_data)

# %%
print(all_books[:5])
# Out:
# [{'title': "It's Only the Himalayas", 'category': 'Travel', 'price': 45.17, 'availability': 'In stock', 'rating': 2, 'product_url': 'https://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html', 'img': 'https://books.toscrape.com/media/cache/6d/41/6d418a73cc7d4ecfd75ca11d854041db.jpg'}, {'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 'category': 'Travel', 'price': 49.43, 'availability': 'In stock', 'rating': 4, 'product_url': 'https://books.toscrape.com/catalogue/full-moon-over-noahs-ark-an-odyssey-to-mount-ararat-and-beyond_811/index.html', 'img': 'https://books.toscrape.com/media/cache/fe/8a/fe8af6ceec7718986380c0fde9b3b34f.jpg'}, {'title': 'See America: A Celebration of Our National Parks & Treasured Sites', 'category': 'Travel', 'price': 48.87, 'availability': 'In stock', 'rating': 3, 'product_url': 'https://books.toscrape.com/catalogue/see-america-a-celebration-of-our-national-parks-treasured-sites_732/index.html', 'img': 'https://boo
# ...

# %%
booksDf=pd.DataFrame(all_books)
booksDf.index+=1
booksDf
# Out:
#                                                   title  category  price  \
# 1                               It's Only the Himalayas    Travel  45.17
# 2     Full Moon over Noah’s Ark: An Odyssey to Mount...    Travel  49.43
# 3     See America: A Celebration of Our National Par...    Travel  48.87
# 4     Vagabonding: An Uncommon Guide to the Art of L...    Travel  36.94
# 5                                  Under the Tuscan Sun    Travel  37.33
# ...                                                 ...       ...    ...
# 996   Why the Right Went Wrong: Conservatism--From G...  Politics  52.65
# 997   Equal Is Unfair: America's Misguided Fight Aga...  Politics  56.86
# 998                                      Amid the Chaos  Cultural  36.58
# 999                                          Dark Notes   Erotica  19.19
# 1000  The Long Shadow of Small Ghosts: Murder and Me...     Crime  10.97
#
#      availability  rating                                        product_url  \
# ...

# %% [markdown]
# **Cleaning**

# %%
booksDf.drop_duplicates(subset='product_url', inplace=True)

# %% [markdown]
# **Perfomance measurement**

# %%
import time
